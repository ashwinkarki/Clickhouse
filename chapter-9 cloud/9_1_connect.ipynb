# %%
#pip install clickhouse-driver
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [clickhouse-driver]
# ...
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from clickhouse_driver import Client

# %%
client = Client(
    host='ddutaqmpsi.us-west-2.aws.clickhouse.cloud',
    user='default',
    password='US14eR3.Rj32.',
    secure=True,
    port=9440
)

# %%
print(client.execute('SELECT 1'))
# Out:
# [(1,)]

# %%
query = """
SELECT *
FROM covid_demo.`covid-new-pipeline`
LIMIT 10
"""

data = client.execute(query)

# %%
import pandas as pd
# Get column names
columns = [col[0] for col in client.execute(
    "DESCRIBE TABLE covid_demo.`covid-new-pipeline`"
)]

df = pd.DataFrame(data, columns=columns)

df.head()
# Out:
#       trip_id  vendor_id pickup_date     pickup_datetime dropoff_date  \
# 0  1200007249          2  2015-07-01 2015-07-01 01:26:21   2015-07-01
# 1  1200007257          1  2015-07-01 2015-07-01 02:09:55   2015-07-01
# 2  1200007260          1  2015-07-01 2015-07-01 01:50:33   2015-07-01
# 3  1200007267          2  2015-07-01 2015-07-01 05:48:49   2015-07-01
# 4  1200007270          2  2015-07-01 2015-07-01 06:17:46   2015-07-01
#
#      dropoff_datetime  store_and_fwd_flag  rate_code_id  pickup_longitude  \
# 0 2015-07-01 01:28:47                   0             2        -73.927589
# 1 2015-07-01 02:19:43                   0             1        -74.005661
# 2 2015-07-01 02:16:04                   0             2        -73.789436
# 3 2015-07-01 05:55:33                   0             1        -73.947304
# 4 2015-07-01 06:52:04                   0             2        -73.985184
#
#    pickup_latitude  ...  dropoff_ct2010  dropoff_boroct2010  \
# ...
