# %%
INSERT INTO events
FORMAT CSV

# %%
docker exec -i clickhouse clickhouse-client --query="INSERT INTO events FORMAT CSV" < events.csv

# %%
docker exec -i clickhouse clickhouse-client --query="INSERT INTO te
stdb.events FORMAT JSONEachRow" < events.json
